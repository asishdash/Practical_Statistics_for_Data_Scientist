# %%
import pandas as pd

# %%
df =pd.read_excel("Data/Olympic_data.xlsx")

# %%
df
# Out:
#                        Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0     United States of America          39            41            33    113
# 1   People's Republic of China          38            32            18     88
# 2                        Japan          27            14            17     58
# 3                Great Britain          22            21            22     65
# 4                          ROC          20            28            23     71
# ..                         ...         ...           ...           ...    ...
# 88                       Ghana           0             0             1      1
# 89                     Grenada           0             0             1      1
# 90                      Kuwait           0             0             1      1
# 91         Republic of Moldova           0             0             1      1
# 92        Syrian Arab Republic           0             0             1      1
#
#     Rank By Total
# ...

# %%
#Frequency
#Plot histogram , Density plot
#Exploring binary and catagorical data
# transpose
#melt
#pie chart
